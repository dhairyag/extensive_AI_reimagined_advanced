# %% [markdown]
# CODE BLOCK: 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from tqdm import tqdm

# %%
# use/update following 4 lines if used in google-drive
#from google.colab import drive
#drive.mount("/content/drive", force_remount=True)
#import sys
#sys.path.append("/content/drive/My Drive/Colab Notebooks/w7_assignment_ERA/")

#from model_02 import Net2

# %% [markdown]
# CODE BLOCK: 2

# %%
# check if CUDA is available
cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)
# Out:
# CUDA Available? True

# %% [markdown]
# CODE BLOCK: 3

# %%
# Train data transformations
train_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
    ])

# Test data transformations
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
    ])

# load data sets for training and testing
train_data = datasets.MNIST('../data', train=True, download=True, transform=train_transforms)
test_data = datasets.MNIST('../data', train=False, download=True, transform=test_transforms) # flag
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 93626126.24it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 26776236.48it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 30616055.52it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 7663125.01it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %% [markdown]
# CODE BLOCK: 4

# %%
# batch size is the number of samples processed before the model is updated
batch_size = 512

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 2, 'pin_memory': True}

test_loader = torch.utils.data.DataLoader(test_data, **kwargs)
train_loader = torch.utils.data.DataLoader(train_data, **kwargs)

# %% [markdown]
# CODE BLOCK: 5

# %%
import matplotlib.pyplot as plt

batch_data, batch_label = next(iter(train_loader))

fig = plt.figure()

for i in range(12):
  plt.subplot(3,4,i+1)
  plt.tight_layout()
  plt.imshow(batch_data[i].squeeze(0), cmap='gray')
  plt.title(batch_label[i].item())
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# CODE BLOCK: 6

# %%
# Data to plot accuracy and loss graphs
train_losses = []
test_losses = []
train_acc = []
test_acc = []

test_incorrect_pred = {'images': [], 'ground_truths': [], 'predicted_vals': []}


def GetCorrectPredCount(pPrediction, pLabels):
  return pPrediction.argmax(dim=1).eq(pLabels).sum().item()

def train(model, device, train_loader, optimizer, criterion):
  model.train()
  pbar = tqdm(train_loader)

  train_loss = 0
  correct = 0
  processed = 0

  for batch_idx, (data, target) in enumerate(pbar):
    data, target = data.to(device), target.to(device)
    optimizer.zero_grad()

    # Predict
    pred = model(data)

    # Calculate loss
    loss = criterion(pred, target)
    train_loss+=loss.item()

    # Backpropagation
    loss.backward()
    optimizer.step()

    correct += GetCorrectPredCount(pred, target)
    processed += len(data)

    pbar.set_description(desc= f'Train: Loss={loss.item():0.4f} Batch_id={batch_idx} Accuracy={100*correct/processed:0.2f}')

  train_acc.append(100*correct/processed)
  train_losses.append(train_loss/len(train_loader))

def test(model, device, test_loader, criterion):
    model.eval()

    test_loss = 0
    correct = 0

    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            data, target = data.to(device), target.to(device)

            output = model(data)
            test_loss += criterion(output, target).item()  # sum up batch loss

            correct += GetCorrectPredCount(output, target)


    test_loss /= len(test_loader.dataset)
    test_acc.append(100. * correct / len(test_loader.dataset))
    test_losses.append(test_loss)

    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# CODE BLOCK: 7

# %%
# model.py

import torch.nn as nn
import torch.nn.functional as F

size1 = 8
size2 = 12
size3 = 16
drop_value = 0.15

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(1, size1, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(size1),
            nn.Dropout(drop_value),
            nn.Conv2d(size1, size1, 3, stride=1, padding=1),
            #
            nn.ReLU(),
            nn.BatchNorm2d(size1),
            nn.Dropout(drop_value),
            nn.Conv2d(size1, size1, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(size1),
            nn.Dropout(drop_value),
            nn.MaxPool2d(2, 2),
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(size1, size2, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(size2),
            nn.Dropout(drop_value),
            nn.Conv2d(size2, size2, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(size2),
            nn.Dropout(drop_value),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(size2, size3, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(size3),
            nn.Dropout(drop_value),
            nn.MaxPool2d(2, 2),
        )


        self.fc = nn.Sequential(
            nn.Linear(144, 10)
        )


    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)

        x = F.log_softmax(x, dim=1)
        return x

from torchsummary import summary

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
summary(model, input_size=(1, 28, 28))

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1, verbose=True)
#
criterion = nn.CrossEntropyLoss()
num_epochs = 15
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#               ReLU-2            [-1, 8, 28, 28]               0
#        BatchNorm2d-3            [-1, 8, 28, 28]              16
#            Dropout-4            [-1, 8, 28, 28]               0
#             Conv2d-5            [-1, 8, 28, 28]             584
#               ReLU-6            [-1, 8, 28, 28]               0
#        BatchNorm2d-7            [-1, 8, 28, 28]              16
#            Dropout-8            [-1, 8, 28, 28]               0
#             Conv2d-9            [-1, 8, 28, 28]             584
#              ReLU-10            [-1, 8, 28, 28]               0
#       BatchNorm2d-11            [-1, 8, 28, 28]              16
#           Dropout-12            [-1, 8, 28, 28]               0
#         MaxPool2d-13            [-1, 8, 14, 14]               0
#            Conv2d-14           [-1, 12, 14, 14]             876
#              ReLU-15           [-1, 12, 14, 14]               0
#       BatchNorm2d-16           [-1, 12, 14, 14]              24
#           Dropout-17           [-1, 12, 14, 14]               0
#            Conv2d-18           [-1, 12, 14, 14]           1,308
#              ReLU-19           [-1, 12, 14, 14]               0
#       BatchNorm2d-20           [-1, 12, 14, 14]              24
#           Dropout-21           [-1, 12, 14, 14]               0
#         MaxPool2d-22             [-1, 12, 7, 7]               0
#            Conv2d-23             [-1, 16, 7, 7]           1,744
#              ReLU-24             [-1, 16, 7, 7]               0
#       BatchNorm2d-25             [-1, 16, 7, 7]              32
#           Dropout-26             [-1, 16, 7, 7]               0
#         MaxPool2d-27             [-1, 16, 3, 3]               0
#            Linear-28                   [-1, 10]           1,450
# ================================================================
# Total params: 6,754
# Trainable params: 6,754
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.76
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.79
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %% [markdown]
# **CODE** BLOCK: 8

# %%
for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train(model, device, train_loader, optimizer, criterion)
  test(model, device, test_loader, criterion)
  scheduler.step()
# Out:
# Epoch 1
# Train: Loss=0.1652 Batch_id=117 Accuracy=84.88: 100%|██████████| 118/118 [00:23<00:00,  5.02it/s]
# Test set: Average loss: 0.0002, Accuracy: 9697/10000 (96.97%)
#
# Epoch 2
# Train: Loss=0.0801 Batch_id=117 Accuracy=96.18: 100%|██████████| 118/118 [00:12<00:00,  9.10it/s]
# Test set: Average loss: 0.0001, Accuracy: 9787/10000 (97.87%)
#
# Epoch 3
# Train: Loss=0.1939 Batch_id=117 Accuracy=96.86: 100%|██████████| 118/118 [00:13<00:00,  9.07it/s]
# Test set: Average loss: 0.0001, Accuracy: 9804/10000 (98.04%)
#
# Epoch 4
# Train: Loss=0.0856 Batch_id=117 Accuracy=97.25: 100%|██████████| 118/118 [00:13<00:00,  8.88it/s]
# Test set: Average loss: 0.0001, Accuracy: 9836/10000 (98.36%)
#
# Epoch 5
# Train: Loss=0.0264 Batch_id=117 Accuracy=97.53: 100%|██████████| 118/118 [00:13<00:00,  9.01it/s]
# Test set: Average loss: 0.0001, Accuracy: 9810/10000 (98.10%)
#
# Epoch 6
# Train: Loss=0.0542 Batch_id=117 Accuracy=97.80: 100%|██████████| 118/118 [00:13<00:00,  8.98it/s]
# Test set: Average loss: 0.0001, Accuracy: 9850/10000 (98.50%)
#
# Epoch 7
# Train: Loss=0.1613 Batch_id=117 Accuracy=97.95: 100%|██████████| 118/118 [00:12<00:00,  9.11it/s]
# Test set: Average loss: 0.0001, Accuracy: 9869/10000 (98.69%)
#
# Epoch 8
# Train: Loss=0.0166 Batch_id=117 Accuracy=98.04: 100%|██████████| 118/118 [00:13<00:00,  8.65it/s]
# Test set: Average loss: 0.0001, Accuracy: 9853/10000 (98.53%)
#
# Epoch 9
# Train: Loss=0.0245 Batch_id=117 Accuracy=98.12: 100%|██████████| 118/118 [00:13<00:00,  8.80it/s]
# Test set: Average loss: 0.0001, Accuracy: 9882/10000 (98.82%)
#
# Epoch 10
# Train: Loss=0.1421 Batch_id=117 Accuracy=98.25: 100%|██████████| 118/118 [00:14<00:00,  8.28it/s]
# Test set: Average loss: 0.0001, Accuracy: 9893/10000 (98.93%)
#
# Epoch 11
# Train: Loss=0.0786 Batch_id=117 Accuracy=98.34: 100%|██████████| 118/118 [00:13<00:00,  8.84it/s]
# Test set: Average loss: 0.0001, Accuracy: 9896/10000 (98.96%)
#
# Epoch 12
# Train: Loss=0.0572 Batch_id=117 Accuracy=98.43: 100%|██████████| 118/118 [00:13<00:00,  8.88it/s]
# Test set: Average loss: 0.0001, Accuracy: 9890/10000 (98.90%)
#
# Epoch 13
# Train: Loss=0.0109 Batch_id=117 Accuracy=98.50: 100%|██████████| 118/118 [00:13<00:00,  8.97it/s]
# Test set: Average loss: 0.0001, Accuracy: 9897/10000 (98.97%)
#
# Epoch 14
# Train: Loss=0.0210 Batch_id=117 Accuracy=98.52: 100%|██████████| 118/118 [00:14<00:00,  8.15it/s]
# Test set: Average loss: 0.0001, Accuracy: 9888/10000 (98.88%)
#
# Epoch 15
# Train: Loss=0.0980 Batch_id=117 Accuracy=98.54: 100%|██████████| 118/118 [00:13<00:00,  8.46it/s]
# Test set: Average loss: 0.0001, Accuracy: 9895/10000 (98.95%)

# %% [markdown]
# **CODE** BLOCK: 9

# %%
fig, axs = plt.subplots(2,2,figsize=(15,10))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
# Out:
# Text(0.5, 1.0, 'Test Accuracy')

# %%
min_train_loss_epoch = train_losses.index(min(train_losses)) + 1
min_test_loss_epoch = test_losses.index(min(test_losses)) + 1
best_train_acc_epoch = train_acc.index(max(train_acc)) + 1
best_test_acc_epoch = test_acc.index(max(test_acc)) + 1

print("Minimum training loss = {:.9f}% at epoch {}".format(min(train_losses), min_train_loss_epoch))
print("Minimum testing loss = {:.9f}% at epoch {}".format(min(test_losses), min_test_loss_epoch))
print("Best training accuracy = {:.2f}% at epoch {}".format(max(train_acc), best_train_acc_epoch))
print("Best testing accuracy = {:.2f}% at epoch {}".format(max(test_acc), best_test_acc_epoch))
# Out:
# Minimum training loss = 0.045337179% at epoch 15
# Minimum testing loss = 0.000062292% at epoch 13
# Best training accuracy = 98.54% at epoch 15
# Best testing accuracy = 98.97% at epoch 13

# %% [markdown]
# ##**Target**

# %% [markdown]
# - Use regularization with dropout (drop value as 0.15)
# - Make model very lighter with less than 8k parameters
# - Use batch normalization
# - Use fully connected layer
# - Use max pooling at appropriate places

# %% [markdown]
# ##**Results:**

# %% [markdown]
# - Total parameters: 6,754
# - Best train accuracy: 98.54% at epoch 15
# - Best test accuracy: 98.97% at epoch 13

# %% [markdown]
# # **Analysis**

# %% [markdown]
# - Regularization has removed overfitting by dropping 15% kernel values every step
# - Image processing with random rotation/crop can be useful to increase test accuracy
