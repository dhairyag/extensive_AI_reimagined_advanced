# %%
# git clone the model repo
import shutil
import sys

# Specify the path to the local repository
repo_path = "./main_ml_models_utils"

try:
    # Delete the directory if it exists
    shutil.rmtree(repo_path)
    print(f"Directory '{repo_path}' deleted successfully.")
except FileNotFoundError:
    print(f"Directory '{repo_path}' does not exist.")

# !pip install -q xlrd
# !git clone https://github.com/dhairyag/main_ml_models_utils
# Out:
# Directory './main_ml_models_utils' deleted successfully.
# Cloning into 'main_ml_models_utils'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 47 (delta 24), reused 32 (delta 12), pack-reused 0
# Receiving objects: 100% (47/47), 10.88 KiB | 10.88 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
import sys
# import repository files
sys.path.append("./main_ml_models_utils")

from main import Model, Train

# get model and train
model = Model()
Train(model)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Epoch 1
#   0%|          | 0/49 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Train: Loss=2.0337 Batch_id=48 Accuracy=17.00: 100%|██████████| 49/49 [00:39<00:00,  1.24it/s]
# Test set: Average loss: 0.0024, Accuracy: 2222/10000 (22.22%)
#
# Epoch 2
# Train: Loss=1.7834 Batch_id=48 Accuracy=29.01: 100%|██████████| 49/49 [00:37<00:00,  1.29it/s]
# Test set: Average loss: 0.0017, Accuracy: 3673/10000 (36.73%)
#
# Epoch 3
# Train: Loss=1.6011 Batch_id=48 Accuracy=36.79: 100%|██████████| 49/49 [00:39<00:00,  1.25it/s]
# Test set: Average loss: 0.0016, Accuracy: 4021/10000 (40.21%)
#
# Epoch 4
# ...

# %%
from utils import plot_loss

# plot loss variation with epochs
plot_loss()

# %%
from utils import misclassified_10

misclassified_10(model)

# %%
import torch
torch.save(model,'model22')

# %%
modd = torch.load('model22')
